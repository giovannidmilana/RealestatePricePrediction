# %%
#f'{x}'
import pandas as pd

import time

import random

import requests

resl = []

url = "https://www.zillow.com/search/GetSearchPageState.htm"

#querystring = {"searchQueryState":"{\"mapBounds\":{\"north\":34.58602654995436,\"south\":34.03246866683238,\"east\":-83.10638773242188,\"west\":-84.61426126757813},\"regionSelection\":[{\"regionId\":24822,\"regionType\":6}],\"isMapVisible\":true,\"filterState\":{\"isAllHomes\":{\"value\":true},\"sortSelection\":{\"value\":\"globalrelevanceex\"}},\"isListVisible\":true,\"pagination\":{\"currentPage\": f'{x}' }}","wants":"{\"cat1\":[\"listResults\",\"mapResults\"],\"cat2\":[\"total\"]}","requestId":"7"}

    ########
    ####{\"pagination\":{\"currentPage\":2}
    ##"{\"pagination\":{\"currentPage\":" + str(x) + "}
    # fill in new headers when aquiring new data from site
#"pagination\":{\"currentPage\": f"{x}" }
it = 46364/40
for x in range(int(it)):
    
    querystring = {"searchQueryState":"{\"usersSearchTerm\":\"GA\",\"mapBounds\":{\"west\":-89.09686235378673,\"east\":-77.03387407253673,\"south\":31.144261349906813,\"north\":35.61897472753755},\"mapZoom\":7,\"regionSelection\":[{\"regionId\":16,\"regionType\":2}],\"isMapVisible\":true,\"filterState\":{\"isAllHomes\":{\"value\":true},\"sortSelection\":{\"value\":\"globalrelevanceex\"}},\"isListVisible\":true,\"pagination\":{\"currentPage\":" + str(x) + "}}","wants":"{\"cat1\":[\"listResults\",\"mapResults\"],\"cat2\":[\"total\"]}","requestId":"11"}

    payload = ""
    headers = {
        "cookie": "AWSALB=%2BW%2BWGDwUrZmk2JHTHIK5S7O0P%2FsvIc9EWgp%2FNAt1Kjv%2FEpU0fswS6a4p7tpJpTRsYoXIWRolSwlnspdG%2FchoH7UTbc5hXh5G6rFt%2BZOIdv9SoULSVETVe8oUYhXK; AWSALBCORS=%2BW%2BWGDwUrZmk2JHTHIK5S7O0P%2FsvIc9EWgp%2FNAt1Kjv%2FEpU0fswS6a4p7tpJpTRsYoXIWRolSwlnspdG%2FchoH7UTbc5hXh5G6rFt%2BZOIdv9SoULSVETVe8oUYhXK; search=6%7C1668137120594%257Crect%253D35.61897472753755%25252C-77.03387407253673%25252C31.144261349906813%25252C-89.09686235378673%2526rid%253D16%2526disp%253Dmap%2526mdm%253Dauto%2526p%253D3%2526z%253D1%2526fs%253D1%2526fr%253D0%2526mmm%253D0%2526rs%253D0%2526ah%253D0%2526singlestory%253D0%2526housing-connector%253D0%2526abo%253D0%2526garage%253D0%2526pool%253D0%2526ac%253D0%2526waterfront%253D0%2526finished%253D0%2526unfinished%253D0%2526cityview%253D0%2526mountainview%253D0%2526parkview%253D0%2526waterview%253D0%2526hoadata%253D1%2526zillow-owned%253D0%25263dhome%253D0%2526featuredMultiFamilyBuilding%253D0%2509%250916%2509%2509%2509%2509%2509%2509; JSESSIONID=113DEDE1D7B7DBB7F76DC1EF90EDF62F",
        "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv
22%2C%22identity%22%3Anull%2C%22trackerVersion%22%3A%224.0%22%7D; gclid=CjwKCAjwqJSaBhBUEiwAg5W9p4ajIkWmrj_MJmz6jRD5PQIGjMcTS8aqVgimPE7ymHv4drE-ToCEahoCb6oQAvD_BwE; _clck=1eao41d|1|f5n|0; _cs_c=0; g_state={"i_p":1665621077866,"i_l":2}; _fbp=fb.1.1665521290484.280979115; _clsk=bos6sj|1665545051619|39|0|l.clarity.ms/collect; _cs_id=9104c928-3754-afb9-cb8b-7af19b5b0438.1665521291.1.1665521291.1665521291.1.1699685291291; AWSALB=g0GqkpQSxGt/4E0daKDz8zlJ9yGrj8dLwKyPwTy/h4f5BbJL5jz2omnd0oPdKRGn28Kj2SIMk/q/u53+yYGB1DQxJtWt4YMtUZ7P5crFRr6zXxqVlzMoCNplJxDF; AWSALBCORS=g0GqkpQSxGt/4E0daKDz8zlJ9yGrj8dLwKyPwTy/h4f5BbJL5jz2omnd0oPdKRGn28Kj2SIMk/q/u53+yYGB1DQxJtWt4YMtUZ7P5crFRr6zXxqVlzMoCNplJxDF; JSESSIONID=F20EFF37B2AAB4CA38E78D608CB89D26; search=6|1668137050056%7Crect%3D35.61897472753755%252C-77.03387407253673%252C31.144261349906813%252C-89.09686235378673%26rid%3D16%26disp%3Dmap%26mdm%3Dauto%26p%3D2%26z%3D1%26fs%3D1%26fr%3D0%26mmm%3D0%26rs%3D0%26ah%3D0%26singlestory%3D0%26housing-connector%3D0%26abo%3D0%26garage%3D0%26pool%3D0%26ac%3D0%26waterfront%3D0%26finished%3D0%26unfinished%3D0%26cityview%3D0%26mountainview%3D0%26parkview%3D0%26waterview%3D0%26hoadata%3D1%26zillow-owned%3D0%263dhome%3D0%26featuredMultiFamilyBuilding%3D0%09%0916%09%09%09%09%09%09; __gads=ID=741ef8edef5e5bef:T=1665521301:S=ALNI_MasghfXnJQGJhKQy47-1y6-Zs_GLw; __gpi=UID=000008d86a98ca4d:T=1665521301:RT=1665543107:S=ALNI_MZ65aU1CT6iVjqbTzefgO3IfhPJzA; KruxAddition=true; G_ENABLED_IDPS=google; _uetsid=02ba99f049a611edb2fa55009014d491; _uetvid=02bab6b049a611ed8e150bffdaec22fa; _gat=1',
        "Sec-Fetch-Dest": "empty",
        "Sec-Fetch-Mode": "cors",
        "Sec-Fetch-Site": "same-origin"
    }
    
    time.sleep(random.randint(0, 6))
    response = requests.request("GET", url, data=payload, headers=headers, params=querystring)

    data = response.json()
    
    #print(response.text)
    
    print(len(i))
    
    for i in data['cat1']['searchResults']['listResults']:
        #print("\n")
        #print(len(i))
        #print("\n")
        resl.append(i)
    
df = pd.json_normalize(resl)
# Out:
# 41
# 41
# 41
# 41
# 42
# 42
# 43
# 41
# 41
# 42
# 41
# 41
# 41
# 45
# 41
# 43
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# ...

# %%
df.to_csv("zillow.csv")

# %%
df.head()
# Out:
#        zpid        id providerListingId  \
# 0  14848050  14848050              None
# 1  83352941  83352941              None
# 2  14647507  14647507              None
# 3  14851157  14851157              None
# 4  14646553  14646553              None
#
#                                               imgSrc hasImage  \
# 0  https://photos.zillowstatic.com/fp/d8595a78acb...     True
# 1  https://photos.zillowstatic.com/fp/1421c4fad9e...     True
# 2  https://photos.zillowstatic.com/fp/8897000d1ad...     True
# 3  https://photos.zillowstatic.com/fp/373cfc77e07...     True
# 4  https://photos.zillowstatic.com/fp/1b0e8b57977...     True
#
#                                            detailUrl statusType  \
# 0  https://www.zillow.com/homedetails/770-Ridgewo...   FOR_SALE
# 1  https://www.zillow.com/homedetails/5264-Hopewe...   FOR_SALE
# 2  https://www.zillow.com/homedetails/9670-Lee-Ci...   FOR_SALE
# 3  https://www.zillow.com/homedetails/1960-Beechw...   FOR_SALE
# ...

# %%
df.to_csv("zillow.csv")
